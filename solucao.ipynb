# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins = pd.read_csv('penguins.csv', index_col=False)

# %%
penguins
# Out:
#         Espece       Ilha  largura do bico  profundidade do bico  \
# 0       Adelie  Torgersen             39.1                  18.7
# 1       Adelie  Torgersen             39.5                  17.4
# 2       Adelie  Torgersen             40.3                  18.0
# 3       Adelie  Torgersen              NaN                   NaN
# 4       Adelie  Torgersen             36.7                  19.3
# ..         ...        ...              ...                   ...
# 339  Chinstrap      Dream             55.8                  19.8
# 340  Chinstrap      Dream             43.5                  18.1
# 341  Chinstrap      Dream             49.6                  18.2
# 342  Chinstrap      Dream             50.8                  19.0
# 343  Chinstrap      Dream             50.2                  18.7
#
#      tamanho da asa  massa corporal    sexo
# 0             181.0          3750.0    male
# 1             186.0          3800.0  female
# 2             195.0          3250.0  female
# ...

# %% [markdown]
# # Dados faltantes

# %%
penguins[penguins.isnull().any(axis=1)]
# Out:
#      Espece       Ilha  largura do bico  profundidade do bico  tamanho da asa  \
# 3    Adelie  Torgersen              NaN                   NaN             NaN
# 8    Adelie  Torgersen             34.1                  18.1           193.0
# 9    Adelie  Torgersen             42.0                  20.2           190.0
# 10   Adelie  Torgersen             37.8                  17.1           186.0
# 11   Adelie  Torgersen             37.8                  17.3           180.0
# 47   Adelie      Dream             37.5                  18.9           179.0
# 178  Gentoo     Biscoe             44.5                  14.3           216.0
# 218  Gentoo     Biscoe             46.2                  14.4           214.0
# 256  Gentoo     Biscoe             47.3                  13.8           216.0
# 268  Gentoo     Biscoe             44.5                  15.7           217.0
# 271  Gentoo     Biscoe              NaN                   NaN             NaN
#
#      massa corporal sexo
# ...

# %%
sns.heatmap(penguins.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Ilha mais frequente

# %%
penguins.Ilha.value_counts()
# Out:
# Ilha
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
sns.histplot(data=penguins, x='Ilha', hue='Ilha')
# Out:
# <Axes: xlabel='Ilha', ylabel='Count'>

# %% [markdown]
# # Espécie mais frequente

# %%
penguins.Espece.value_counts()
# Out:
# Espece
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.histplot(data=penguins, x='Espece', hue='Espece')
# Out:
# <Axes: xlabel='Espece', ylabel='Count'>

# %% [markdown]
# # Relação medidas especie

# %%
sns.pairplot(penguins, hue='Espece')
# Out:
# C:\Users\guido.mainardi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Relação entre medidas e sexo para cada Espécie

# %%
Adelie = penguins[penguins.Espece == 'Adelie']
Gentoo = penguins[penguins.Espece == 'Gentoo']
Chinstrap = penguins[penguins.Espece == 'Chinstrap']

# %%
sns.pairplot(Adelie, hue='sexo')
# Out:
# C:\Users\guido.mainardi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(Gentoo, hue='sexo')
# Out:
# C:\Users\guido.mainardi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(Chinstrap, hue='sexo')
# Out:
# C:\Users\guido.mainardi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
