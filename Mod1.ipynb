# %%
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pinguins = pd.read_csv("Anexo_pinguins-2.csv", index_col=False)

# %%
df_pinguins
# Out:
#         Espece       Ilha  largura do bico  profundidade do bico  \
# 0       Adelie  Torgersen             39.1                  18.7
# 1       Adelie  Torgersen             39.5                  17.4
# 2       Adelie  Torgersen             40.3                  18.0
# 3       Adelie  Torgersen              NaN                   NaN
# 4       Adelie  Torgersen             36.7                  19.3
# ..         ...        ...              ...                   ...
# 339  Chinstrap      Dream             55.8                  19.8
# 340  Chinstrap      Dream             43.5                  18.1
# 341  Chinstrap      Dream             49.6                  18.2
# 342  Chinstrap      Dream             50.8                  19.0
# 343  Chinstrap      Dream             50.2                  18.7
#
#      profundidade do bico.1  massa corporal    sexo
# 0                     181.0          3750.0    male
# 1                     186.0          3800.0  female
# ...

# %%
num_linhas = df_pinguins.shape[0]

print('linhas: ', num_linhas)
# Out:
# linhas:  344

# %%
print(tabulate(df_pinguins.head(), headers='keys', tablefmt='pretty'))
# Out:
# +---+--------+-----------+-----------------+----------------------+------------------------+----------------+--------+
# |   | Espece |   Ilha    | largura do bico | profundidade do bico | profundidade do bico.1 | massa corporal |  sexo  |
# +---+--------+-----------+-----------------+----------------------+------------------------+----------------+--------+
# | 0 | Adelie | Torgersen |      39.1       |         18.7         |         181.0          |     3750.0     |  male  |
# | 1 | Adelie | Torgersen |      39.5       |         17.4         |         186.0          |     3800.0     | female |
# | 2 | Adelie | Torgersen |      40.3       |         18.0         |         195.0          |     3250.0     | female |
# | 3 | Adelie | Torgersen |       nan       |         nan          |          nan           |      nan       |  nan   |
# | 4 | Adelie | Torgersen |      36.7       |         19.3         |         193.0          |     3450.0     | female |
# ...

# %%
print("Colunas presentes:", df_pinguins.columns)
# Out:
# Colunas presentes: Index(['Espece', 'Ilha', 'largura do bico', 'profundidade do bico',
#        'profundidade do bico.1', 'massa corporal', 'sexo'],
#       dtype='object')

# %%
# Verificar pinguins sem anotações
pinguins_sem_anotacoes = df_pinguins[df_pinguins.isnull().any(axis=1)]

print(pinguins_sem_anotacoes)
# Out:
#      Espece       Ilha  largura do bico  profundidade do bico  \
# 3    Adelie  Torgersen              NaN                   NaN
# 8    Adelie  Torgersen             34.1                  18.1
# 9    Adelie  Torgersen             42.0                  20.2
# 10   Adelie  Torgersen             37.8                  17.1
# 11   Adelie  Torgersen             37.8                  17.3
# 47   Adelie      Dream             37.5                  18.9
# 178  Gentoo     Biscoe             44.5                  14.3
# 218  Gentoo     Biscoe             46.2                  14.4
# 256  Gentoo     Biscoe             47.3                  13.8
# 268  Gentoo     Biscoe             44.5                  15.7
# 271  Gentoo     Biscoe              NaN                   NaN
#
#      profundidade do bico.1  massa corporal sexo
# 3                       NaN             NaN  NaN
# 8                     193.0          3475.0  NaN
# 9                     190.0          4250.0  NaN
# ...

# %%
# Contar a frequência de ilhas
frequencia_ilhas = df_pinguins['Ilha'].value_counts()
print(frequencia_ilhas)
# Out:
# Ilha
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# Contar a frequência das espécies
frequencia_especies = df_pinguins['Espece'].value_counts()
print(frequencia_especies)
# Out:
# Espece
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Scatter plot para Largura do Bico vs. Profundidade do Bico colorido por Espécie
sns.scatterplot(data=df_pinguins, x='largura do bico', y='profundidade do bico', hue='Espece')
plt.show()

# Boxplot de Massa Corporal por Espécie
sns.boxplot(data=df_pinguins, x='Espece', y='massa corporal')
plt.show()

# %%
# Boxplot de Largura do Bico por Sexo, dividido por Espécie
sns.boxplot(data=df_pinguins, x='Espece', y='largura do bico', hue='sexo')
plt.show()

# %%
import matplotlib.pyplot as plt

# Gráfico de dispersão para largura do bico e profundidade do bico
plt.figure(figsize=(10, 6))
for especie in df_pinguins['Espece'].unique():
    subset = df_pinguins[df_pinguins['Espece'] == especie]
    plt.scatter(subset['largura do bico'], subset['profundidade do bico'], label=especie)

# Configurações do gráfico
plt.xlabel('Largura do Bico (mm)')
plt.ylabel('Profundidade do Bico (mm)')
plt.title('Relação entre Medidas do Pinguim e Espécie')
plt.legend()
plt.grid(True)
plt.show()
